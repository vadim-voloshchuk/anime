# %%
import pandas as pd

data = pd.read_csv('server/data/all_data.csv')

# %%
data
# Out:
#         in_id                                              query  \
# 0     19749.0  Вопрос 7. Что должны сделать Лидеры безопаснос...
# 1     19749.0  Вопрос 7. Что должны сделать Лидеры безопаснос...
# 2     19749.0  Вопрос 7. Что должны сделать Лидеры безопаснос...
# 3     19749.0  Вопрос 7. Что должны сделать Лидеры безопаснос...
# 4     19749.0  Вопрос 7. Что должны сделать Лидеры безопаснос...
# ...       ...                                                ...
# 5234  28569.0                       Сетевое взаимодействие - это
# 5235  28569.0                       Сетевое взаимодействие - это
# 5236  28569.0                       Сетевое взаимодействие - это
# 5237  28569.0                       Сетевое взаимодействие - это
# 5238  28569.0                       Сетевое взаимодействие - это
#
#                                            answers_text  answers_count  \
# 0                        создание раб.групп для контрол            1.0
# ...

# %%
data['answers_sentiment'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
data['answers_count'].sort_values().plot()
# Out:
# <Axes: >

# %%
data['answers_count'].to_frame('answers_count').boxplot(meanline=True, showmeans=True)
# Out:
# <Axes: >

# %%
country = data.groupby("query")

country.describe().head()
# Out:
#                                                     in_id                \
#                                                     count     mean  std
# query
# 1. Топ 3 дефицита компетенций по безопасности у...   20.0  21586.0  0.0
# 20.\tКакие моменты мероприятия Вам наиболее пон...   34.0  21111.0  0.0
# 2021 год для меня в Академии – это…                  40.0   1613.0  0.0
# 21. Что на Ваш взгляд можно добавить/изменить в...   35.0  21112.0  0.0
# 5 слов, которые характеризуют произошедшее с ва...  114.0   5080.0  0.0
#
#                                                                                \
#                                                         min      25%      50%
# query
# 1. Топ 3 дефицита компетенций по безопасности у...  21586.0  21586.0  21586.0
# 20.\tКакие моменты мероприятия Вам наиболее пон...  21111.0  21111.0  21111.0
# 2021 год для меня в Академии – это…                  1613.0   1613.0   1613.0
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
country.size().sort_values(ascending=False)[:50].plot.bar()
# Out:
# <Axes: xlabel='query'>
# ) missing from current font.ng\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 13 (
#   func(*args, **kwargs)
# C:\Users\kingo\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 9 (	) missing from current font.
#   func(*args, **kwargs)
# ) missing from current font.ng\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 13 (
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kingo\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
